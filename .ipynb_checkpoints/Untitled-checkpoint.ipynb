# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('data.csv')

# %%
data.head(5)
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
data.iloc[:, 2:]
# Out:
#                        Name  Age  \
# 0                  L. Messi   31
# 1         Cristiano Ronaldo   33
# 2                 Neymar Jr   26
# 3                    De Gea   27
# 4              K. De Bruyne   27
# 5                 E. Hazard   27
# 6                 L. Modrić   32
# 7                 L. Suárez   31
# 8              Sergio Ramos   32
# 9                  J. Oblak   25
# 10           R. Lewandowski   29
# 11                 T. Kroos   28
# 12                 D. Godín   32
# 13              David Silva   32
# 14                 N. Kanté   27
# 15                P. Dybala   24
# 16                  H. Kane   24
# 17             A. Griezmann   27
# 18            M. ter Stegen   26
# 19              T. Courtois   26
# 20          Sergio Busquets   29
# 21                E. Cavani   31
# 22                 M. Neuer   32
# 23                S. Agüero   30
# 24             G. Chiellini   33
# 25                K. Mbappé   19
# 26                 M. Salah   26
# ...

# %%
data.dropna(subset=['Age'],inplace=True)
data.dropna(subset=['Nationality'],inplace=True)
data.dropna(subset=['Overall'],inplace=True)
data.dropna(subset=['Potential'],inplace=True)
data.dropna(subset=['Value'],inplace=True)
data.dropna(subset=['Composure'],inplace=True)
data.dropna(subset=['Marking'],inplace=True)
data.dropna(subset=['StandingTackle'],inplace=True)
data.dropna(subset=['SlidingTackle'],inplace=True)
data.dropna(subset=['GKDiving'],inplace=True)
data.dropna(subset=['GKHandling'],inplace=True)
data.dropna(subset=['GKKicking'],inplace=True)
data.dropna(subset=['GKPositioning'],inplace=True)
data.dropna(subset=['GKReflexes'],inplace=True)
data.dropna(subset=['Release Clause'],inplace=True)

# %%
data.shape
# Out:
# (16643, 89)
